# %%
import matplotlib.pyplot as plt 
import pandas as pd

# %%
df=pd.read_csv('data/processed/dataset_master.csv')

plt.figure(figsize=(6, 4))
plt.boxplot(df['CDR'].dropna())
plt.title("Boxplot of CDR")
plt.ylabel("CDR Value")
plt.show()
